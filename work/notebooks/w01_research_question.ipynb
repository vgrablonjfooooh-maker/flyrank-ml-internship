# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### My lane: Refresh / Content Opportunity Scoring

I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying pages that should be reviewed first. This lane uses observable search and engagement signals to rank pages by their need for content updates. It can help the SEO team prioritize work instead of reviewing every page manually.
"""))
# Out:
# ### My lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying pages that should be reviewed first. This lane uses observable search and engagement signals to rank pages by their need for content updates. It can help the SEO team prioritize work instead of reviewing every page manually.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Decision
Which pages should be reviewed and updated first?

### Action
The SEO/content team reviews the highest-ranked pages and improves their content.

### Cost of a wrong call
If the wrong pages are selected, time and effort are wasted on pages that do not need updates, while important declining pages continue to lose traffic and visibility.
"""))
# Out:
# ### Decision
# Which pages should be reviewed and updated first?
#
# ### Action
# The SEO/content team reviews the highest-ranked pages and improves their content.
#
# ### Cost of a wrong call
# If the wrong pages are selected, time and effort are wasted on pages that do not need updates, while important declining pages continue to lose traffic and visibility.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### What my work can claim
This project uses observed search and engagement data to identify pages that may need review. It provides decision support by ranking pages based on measurable signals.

### What my work cannot claim
This project cannot prove that updating a page will increase traffic or improve Google rankings. It identifies opportunities, but the final decision and results depend on human review and future outcomes.
"""))
# Out:
# ### What my work can claim
# This project uses observed search and engagement data to identify pages that may need review. It provides decision support by ranking pages based on measurable signals.
#
# ### What my work cannot claim
# This project cannot prove that updating a page will increase traffic or improve Google rankings. It identifies opportunities, but the final decision and results depend on human review and future outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
