# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("Classification")
print("This is a classification task because the model predicts which category an input belongs to.")
# Out:
# Classification
# This is a classification task because the model predicts which category an input belongs to.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("Target: Predict whether an example belongs to a specific class based on its features.")
print("The label comes from observed outcomes in the dataset.")
# Out:
# Target: Predict whether an example belongs to a specific class based on its features.
# The label comes from observed outcomes in the dataset.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("Accuracy")
print("A good model should achieve high prediction accuracy on unseen data.")
# Out:
# Accuracy
# A good model should achieve high prediction accuracy on unseen data.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.DataFrame({
    "feature_1": [10, 20, 30],
    "feature_2": ["A", "B", "C"],
    "target": ["Yes", "No", "Yes"]
})

df
# Out:
#    feature_1 feature_2 target
# 0         10         A    Yes
# 1         20         B     No
# 2         30         C    Yes

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("Machine learning can learn complex patterns from data that are difficult to capture with fixed if-else rules. It adapts better to new and unseen examples.")
# Out:
# Machine learning can learn complex patterns from data that are difficult to capture with fixed if-else rules. It adapts better to new and unseen examples.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
