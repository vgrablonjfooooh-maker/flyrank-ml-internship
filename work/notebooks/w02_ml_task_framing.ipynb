# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# Task Type: Classification
#
# The goal is to classify content based on its performance using content and SEO features.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The target is the `trend_direction` column.
#
# The model predicts whether content is improving, stable, or declining based on its features.
#
# The labels come from observed outcomes in the dataset.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# Accuracy is the primary evaluation metric. A good model should achieve high accuracy on unseen data while correctly predicting the content trend direction.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## The unit of analysis
#
# One row represents one content page.
#
# Each row includes SEO, content, and performance features such as search volume, competition, CTR, average position, engagement rate, and the observed trend direction.

# %%
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")
df.head()
print(df.shape)
print(df.columns)
# Out:
# (30000, 44)
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule
#
# Content performance depends on many interacting factors such as search volume, competition, CTR, average position, engagement, and content characteristics.
#
# A fixed if-else rule cannot capture these complex relationships, while machine learning can learn patterns from historical data and make better predictions for new content.
#
# The prediction can help decide whether a content page should be updated, optimized, or left unchanged.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
