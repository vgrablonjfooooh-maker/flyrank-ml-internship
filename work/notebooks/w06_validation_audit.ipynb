# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
paper_findings = """
Finding 1:
The paper reports that AI-assisted content can achieve strong SEO performance.
Question:
Where do the labels come from? Are they based on real search performance or internal scoring metrics?
The claim is interesting, but more details about label generation would improve confidence.

Finding 2:
The paper suggests that content characteristics such as intent and structure influence outcomes.
Question:
Was the validation performed across different clients and time periods?
A grouped or time-aware validation would help show that the finding generalizes beyond specific datasets.
"""

print(paper_findings)
# Out:
# Finding 1:
# The paper reports that AI-assisted content can achieve strong SEO performance.
# Question:
# Where do the labels come from? Are they based on real search performance or internal scoring metrics?
# The claim is interesting, but more details about label generation would improve confidence.
#
# Finding 2:
# The paper suggests that content characteristics such as intent and structure influence outcomes.
# Question:
# Was the validation performed across different clients and time periods?
# A grouped or time-aware validation would help show that the finding generalizes beyond specific datasets.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
print("""
Week 5 Model Evaluation

Original Split:
The model was evaluated using a standard random train/test split.

Results:
MAE = 0.015586
MSE = 0.016527
R² = 0.976225

Honest Validation Reflection:
The very high R² score may be optimistic because a random split can allow related samples to appear in both training and testing sets.

If a grouped or time-aware split were used, performance might decrease, providing a more realistic estimate of real-world behavior.

Conclusion:
The reported performance is strong, but additional validation using grouped or time-based splitting would increase confidence in the results.
""")
# Out:
# Week 5 Model Evaluation
#
# Original Split:
# The model was evaluated using a standard random train/test split.
#
# Results:
# MAE = 0.015586
# MSE = 0.016527
# R² = 0.976225
#
# Honest Validation Reflection:
# The very high R² score may be optimistic because a random split can allow related samples to appear in both training and testing sets.
#
# If a grouped or time-aware split were used, performance might decrease, providing a more realistic estimate of real-world behavior.
#
# Conclusion:
# The reported performance is strong, but additional validation using grouped or time-based splitting would increase confidence in the results.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
print("""
Leakage Audit

Potential leakage sources:

1. Similar records may appear in both training and testing sets.
2. Some features may indirectly contain information related to the target.
3. Random splitting can create overlap between related observations.

Mitigation:

- Use GroupKFold when group identifiers are available.
- Use TimeSeriesSplit for time-based data.
- Verify that all features are available at prediction time.
""")
# Out:
# Leakage Audit
#
# Potential leakage sources:
#
# 1. Similar records may appear in both training and testing sets.
# 2. Some features may indirectly contain information related to the target.
# 3. Random splitting can create overlap between related observations.
#
# Mitigation:
#
# - Use GroupKFold when group identifiers are available.
# - Use TimeSeriesSplit for time-based data.
# - Verify that all features are available at prediction time.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
print("""
Original Claim:
My model accurately predicts CTR and provides highly reliable results.

Observed Result:
The model achieved an R² score of 0.976 on the evaluation split used in this project.

Safer Claim:
The measured results suggest that the model can estimate CTR effectively on this dataset. These findings should be considered decision-support evidence, and additional validation on unseen data is recommended before making broader conclusions.
""")
# Out:
# Original Claim:
# My model accurately predicts CTR and provides highly reliable results.
#
# Observed Result:
# The model achieved an R² score of 0.976 on the evaluation split used in this project.
#
# Safer Claim:
# The measured results suggest that the model can estimate CTR effectively on this dataset. These findings should be considered decision-support evidence, and additional validation on unseen data is recommended before making broader conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
